# %% [markdown]
# Equities market-risk workflow (steel sector) — with line-by-line comments.
#
# Covers:
# 1) Download daily OHLCV for a single stock + peers + market index
# 2) Build returns, quick stats, beta (OLS), 99% Historical VaR
# 3) Matplotlib charts: price, returns histogram, rolling vol, beta scatter
# 4) Peers comparison: normalized price + correlation heatmap
# 5) Optional intraday (5-minute) pull + rough daily vol

# %%
import yfinance as yf
import pandas as pd 
import numpy as np
import matplotlib. pyplot as plt
import statsmodels.api as sm
import warnings, sys
warnings.filterwarnings ('ignore')

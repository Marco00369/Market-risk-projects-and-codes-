# %% [markdown]
# Market data for Currencies

# %%
pip install forex_python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: forex_python in c:\users\naidu\appdata\roaming\python\python313\site-packages (1.9.2)
# Requirement already satisfied: requests>=2.0 in c:\programdata\anaconda3\lib\site-packages (from forex_python) (2.32.3)
# Requirement already satisfied: simplejson>=3.0 in c:\users\naidu\appdata\roaming\python\python313\site-packages (from forex_python) (3.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.0->forex_python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.0->forex_python) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.0->forex_python) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.0->forex_python) (2025.6.15)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# import libraries

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from forex_python.converter import CurrencyRates,CurrencyCodes
from datetime import datetime as dt,date
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
CCYs = {
    'DM': ('AUD','CAD','CHF','DKK','EUR','GBP','HKD','JPY','NOK','NZD','SEK','SGD'),
    'EM': ('BRL','CLP','CNY','COP','CZK','HUF','IDR','INR','KRW','MXN','MYR','PEN','PHP','PLN','RUB','THB','TRY','ZAR'),
    'FM': ('ARS','BDT','EGP','GHS','KES','NGN','PKR','TND','VND')}
print(CCYs)
# Out:
# {'DM': ('AUD', 'CAD', 'CHF', 'DKK', 'EUR', 'GBP', 'HKD', 'JPY', 'NOK', 'NZD', 'SEK', 'SGD'), 'EM': ('BRL', 'CLP', 'CNY', 'COP', 'CZK', 'HUF', 'IDR', 'INR', 'KRW', 'MXN', 'MYR', 'PEN', 'PHP', 'PLN', 'RUB', 'THB', 'TRY', 'ZAR'), 'FM': ('ARS', 'BDT', 'EGP', 'GHS', 'KES', 'NGN', 'PKR', 'TND', 'VND')}

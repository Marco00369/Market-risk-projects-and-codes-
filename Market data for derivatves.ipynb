# %%
## Market dta for deraitives

# %%
pip install nsepython
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import nsepython as nsepy
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Data Extarction

# %% [markdown]
# Equity spotdata

# %%
SpotData=nsepy.get_bhavcopy(date='13-09-2024').drop(columns =' DATE1').set_index('SYMBOL')
SpotData
# Out:
#            SERIES  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  LAST_PRICE  \
# SYMBOL
# 1018GS2026     GS      127.67      134.00      134.00     121.28      121.28
# 20MICRONS      EQ      304.35      304.90      314.80     304.90      309.00
# 21STCENMGM     BE      134.21      131.52      131.52     131.52      131.52
# 360ONE         EQ     1108.15     1110.00     1110.00    1072.10     1093.00
# 3IINFOLTD      EQ       33.23       33.42       34.20      33.35       33.78
# ...           ...         ...         ...         ...        ...         ...
# ZTECH          SM      362.45      362.45      371.90     360.65      364.60
# ZUARI          EQ      191.38      191.89      196.60     191.56      196.00
# ZUARIIND       EQ      365.85      367.70      378.10     365.25      377.55
# ZYDUSLIFE      EQ     1120.10     1125.60     1125.60    1111.45     1119.00
# ZYDUSWELL      EQ     2238.40     2249.95     2249.95    2197.00     2208.00
#
# ...

# %%
print(SpotData.columns)
# Out:
# Index([' SERIES', ' PREV_CLOSE', ' OPEN_PRICE', ' HIGH_PRICE', ' LOW_PRICE',
#        ' LAST_PRICE', ' CLOSE_PRICE', ' AVG_PRICE', ' TTL_TRD_QNTY',
#        ' TURNOVER_LACS', ' NO_OF_TRADES', ' DELIV_QTY', ' DELIV_PER'],
#       dtype='object')

# %%
SpotData= nsepy.equity_history(symbol='HDFCBANK',series='EQ',start_date='01-01-2023',end_date='01-01-2024')
SpotData
# Out:
#                           _id CH_SYMBOL CH_SERIES CH_MARKET_TYPE  \
# 0    658c11ddf964ff32e77dc099  HDFCBANK        EQ              N
# 1    658d635afc7c264717dac029  HDFCBANK        EQ              N
# 2    658eb4fdbc28d99b03074914  HDFCBANK        EQ              N
# 3    6592a97d1f3097105c5a15e8  HDFCBANK        EQ              N
# 4    655755fdba15dff83b493abc  HDFCBANK        EQ              N
# ..                        ...       ...       ...            ...
# 248  63e0ebfee9486e000641a46a  HDFCBANK        EQ              N
# 249  63e23d7d9029740006c91fb3  HDFCBANK        EQ              N
# 250  63e38edb77e63d0007d9b640  HDFCBANK        EQ              N
# 251  63e4e0621df6cc0007b3d10e  HDFCBANK        EQ              N
# 252  642835e6faf76300072eef10  HDFCBANK        EQ              N
#
#      CH_TRADE_HIGH_PRICE  CH_TRADE_LOW_PRICE  CH_OPENING_PRICE  \
# 0                1706.50             1678.60           1681.50
# ...

# %%
##Equity Spot Index data

# %%
indexData=nsepy.index_history(symbol='Nifty 50',start_date='01-01-2024',end_date='01-01-2025')
indexData
# Out:
#                RequestNumber Index Name INDEX_NAME HistoricalDate      OPEN  \
# 0    His63898107678760715100              Nifty 50    01 Jan 2025  23637.65
# 1    His63898107678760715100              Nifty 50    31 Dec 2024   23560.6
# 2    His63898107678760715100              Nifty 50    30 Dec 2024   23796.9
# 3    His63898107678760715100              Nifty 50    27 Dec 2024   23801.4
# 4    His63898107678760715100              Nifty 50    26 Dec 2024   23775.8
# ..                       ...        ...        ...            ...       ...
# 245  His63898107678760715100              Nifty 50    05 Jan 2024  21705.75
# 246  His63898107678760715100              Nifty 50    04 Jan 2024  21605.80
# 247  His63898107678760715100              Nifty 50    03 Jan 2024  21661.10
# 248  His63898107678760715100              Nifty 50    02 Jan 2024  21751.35
# 249  His63898107678760715100              Nifty 50    01 Jan 2024  21727.75
#
#          HIGH       LOW     CLOSE
# ...

# %%
## Equity Options

# %%
optionsData=nsepy.derivative_history(symbol='SBIN', start_date='01-01-2024', end_date='01-01-2025',instrumentType='options' , expiry_date='29-Feb-2024',strikePrice=500,optionType='CE')
optionsData
# Out:
#                          _id FH_INSTRUMENT FH_SYMBOL FH_EXPIRY_DT  \
# 0   65ca1bab6add4a917d3a107a        OPTSTK      SBIN  29-Feb-2024
# 1   65cb67106add4a917d75c76f        OPTSTK      SBIN  29-Feb-2024
# 2   65ccd62c6add4a917daea484        OPTSTK      SBIN  29-Feb-2024
# 3   65ce15146add4a917de1ef32        OPTSTK      SBIN  29-Feb-2024
# 4   65cf73f56add4a917d18cf42        OPTSTK      SBIN  29-Feb-2024
# 5   65d34eb355959afb0f927a23        OPTSTK      SBIN  29-Feb-2024
# 6   65d4aa7d55959afb0fca5b9d        OPTSTK      SBIN  29-Feb-2024
# 7   65d5fdc255959afb0fffae21        OPTSTK      SBIN  29-Feb-2024
# 8   65d74ee655959afb0f34e6df        OPTSTK      SBIN  29-Feb-2024
# 9   65d8971055959afb0f68addb        OPTSTK      SBIN  29-Feb-2024
# 10  65dffbcbcba52670254a5a7b        OPTSTK      SBIN  29-Feb-2024
# 11  65df6edbcba526702537b6cd        OPTSTK      SBIN  29-Feb-2024
# 12  65df6edacba5267025374c7b        OPTSTK      SBIN  29-Feb-2024
# ...

# %% [raw]
# equity Future Data

# %%
futuresData= nsepy.derivative_history(symbol='SBIN',start_date='01-01-2024',end_date='01-01-2025',instrumentType='futures', expiry_date='29-FEB-2024')
futuresData
# Out:
#                          _id FH_INSTRUMENT FH_SYMBOL FH_EXPIRY_DT  \
# 0   65ca1b8a7e26484fc0413056        FUTSTK      SBIN  29-Feb-2024
# 1   65cb66f17e26484fc07753e0        FUTSTK      SBIN  29-Feb-2024
# 2   65ccd6017e26484fc097246d        FUTSTK      SBIN  29-Feb-2024
# 3   65ce14f97e26484fc0b28844        FUTSTK      SBIN  29-Feb-2024
# 4   65cf739a7e26484fc0d055fc        FUTSTK      SBIN  29-Feb-2024
# 5   65d34e567e26484fc017c458        FUTSTK      SBIN  29-Feb-2024
# 6   65d4aa1f7e26484fc0355551        FUTSTK      SBIN  29-Feb-2024
# 7   65d5fdc27e26484fc051046c        FUTSTK      SBIN  29-Feb-2024
# 8   65d74e887e26484fc06c8c64        FUTSTK      SBIN  29-Feb-2024
# 9   65d896a57e26484fc0875085        FUTSTK      SBIN  29-Feb-2024
# 10  65dca7ac45d82dd6cb56f699        FUTSTK      SBIN  29-Feb-2024
# 11  65dddf1145d82dd6cb6f8719        FUTSTK      SBIN  29-Feb-2024
# 12  65df464345d82dd6cb8d8630        FUTSTK      SBIN  29-Feb-2024
# ...

# %% [raw]
# Additional Data

# %%
print(nsepy.indices)
# Out:
# ['NIFTY', 'FINNIFTY', 'BANKNIFTY']

# %%
print(len(nsepy.fnolist()),nsepy.fnolist())
# Out:
# 212 ['NIFTY', 'NIFTYIT', 'BANKNIFTY', 'LTF', 'BSE', 'ANGELONE', 'KFINTECH', 'IDEA', 'POWERINDIA', 'LICI', 'BANKINDIA', 'SHRIRAMFIN', 'ABCAPITAL', 'AUBANK', 'CDSL', 'BAJFINANCE', 'ADANIENT', 'TATASTEEL', 'BRITANNIA', 'VOLTAS', 'BAJAJFINSV', 'MFSL', 'ICICIPRULI', 'UPL', 'JINDALSTEL', 'VEDL', 'UNIONBANK', 'SAIL', 'HDFCLIFE', 'PAYTM', 'M&M', 'MCX', 'NBCC', 'HUDCO', 'NATIONALUM', 'POLICYBZR', 'SBILIFE', 'ICICIBANK', 'HINDZINC', 'CAMS', 'SOLARINDS', 'BHEL', 'PNB', 'MAZDOCK', 'NMDC', 'SONACOMS', 'INDUSINDBK', 'BEL', 'NAUKRI', 'GMRAIRPORT', 'PETRONET', 'MUTHOOTFIN', 'IDFCFIRSTB', 'EICHERMOT', 'CANBK', 'IRFC', 'YESBANK', 'FORTIS', 'GAIL', 'BANKBARODA', 'CHOLAFIN', 'APLAPOLLO', 'MAXHEALTH', 'IIFL', 'INDIANB', 'PHOENIXLTD', 'IREDA', 'RBLBANK', 'GRASIM', 'ZYDUSLIFE', 'UNITDSPR', 'HDFCAMC', 'HAL', 'ICICIGI', 'ADANIPORTS', 'KEI', 'TORNTPHARM', 'INFY', 'COALINDIA', 'FEDERALBNK', 'LUPIN', 'IEX', 'BANDHANBNK', 'GLENMARK', 'IGL', 'TVSMOTOR', 'RECLTD', 'PRESTIGE', 'HINDPETRO', 'TATAPOWER', 'TORNTPOWER'
# ...

# %%
print(nsepy.nse_eq('HDFCBANK'))
# Out:
# {'info': {'symbol': 'HDFCBANK', 'companyName': 'HDFC Bank Limited', 'industry': 'Private Sector Bank', 'activeSeries': ['EQ', 'T0'], 'debtSeries': [], 'isFNOSec': True, 'isCASec': False, 'isSLBSec': True, 'isDebtSec': True, 'isSuspended': False, 'tempSuspendedSeries': ['W3', 'IL'], 'isETFSec': False, 'isDelisted': False, 'isin': 'INE040A01034', 'slb_isin': 'INE040A01034', 'listingDate': '1995-11-08', 'isMunicipalBond': False, 'isHybridSymbol': False, 'isTop10': False, 'identifier': 'HDFCBANKEQN'}, 'metadata': {'series': 'EQ', 'symbol': 'HDFCBANK', 'isin': 'INE040A01034', 'status': 'Listed', 'listingDate': '08-Nov-1995', 'industry': 'Private Sector Bank', 'lastUpdateTime': '07-Nov-2025 15:51:26', 'pdSectorPe': 20.73, 'pdSymbolPe': 21, 'pdSectorInd': 'NIFTY 50', 'pdSectorIndAll': ['NIFTY 50', 'NIFTY BANK', 'NIFTY FINANCIAL SERVICES', 'NIFTY QUALITY LOW-VOLATILITY 30', 'NIFTY200 MOMENTUM 30', 'NIFTY50 EQUAL WEIGHT', 'NIFTY100 LOW VOLATILITY 30', 'NIFTY100 ESG SECTOR LEADERS', 'NIFTY LAR
# ...

# %%
print(nsepy.nse_fno('HDFCBANK'))
# Out:
# {'info': {'symbol': 'HDFCBANK', 'companyName': 'HDFC Bank Limited', 'industry': 'Private Sector Bank', 'activeSeries': ['EQ', 'T0'], 'debtSeries': [], 'isFNOSec': True, 'isCASec': False, 'isSLBSec': True, 'isDebtSec': True, 'isSuspended': False, 'tempSuspendedSeries': ['W3', 'IL'], 'isETFSec': False, 'isDelisted': False, 'isin': 'INE040A01034', 'slb_isin': 'INE040A01034', 'listingDate': '1995-11-08', 'isMunicipalBond': False, 'isHybridSymbol': False}, 'underlyingValue': 984.3, 'vfq': 27501, 'fut_timestamp': '07-Nov-2025 15:30:05', 'opt_timestamp': '07-Nov-2025 15:30:10', 'stocks': [{'metadata': {'instrumentType': 'Stock Futures', 'expiryDate': '25-Nov-2025', 'optionType': '-', 'strikePrice': 0, 'identifier': 'FUTSTKHDFCBANK25-11-2025XX0.00', 'openPrice': 985.05, 'highPrice': 989.9, 'lowPrice': 979.55, 'closePrice': 0, 'prevClose': 989.8, 'lastPrice': 988.05, 'change': -1.75, 'pChange': -0.1768033946251768, 'numberOfContractsTraded': 24765, 'totalTurnover': 134178.01}, 'underlyingValu
# ...

# %%
optionchain= nsepy.nse_optionchain_scrapper('HDFCBANK')
print(optionchain)
# Out:
# {'records': {'expiryDates': ['25-Nov-2025', '30-Dec-2025', '27-Jan-2026'], 'data': [{'strikePrice': 800, 'expiryDate': '25-Nov-2025', 'PE': {'strikePrice': 800, 'expiryDate': '25-Nov-2025', 'underlying': 'HDFCBANK', 'identifier': 'OPTSTKHDFCBANK25-11-2025PE800.00', 'openInterest': 105, 'changeinOpenInterest': 3, 'pchangeinOpenInterest': 2.9411764705882355, 'totalTradedVolume': 12, 'impliedVolatility': 0, 'lastPrice': 0.15, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 28600, 'totalSellQuantity': 19250, 'bidQty': 7700, 'bidprice': 0.15, 'askQty': 1100, 'askPrice': 0.25, 'underlyingValue': 984.3}}, {'strikePrice': 850, 'expiryDate': '25-Nov-2025', 'CE': {'strikePrice': 850, 'expiryDate': '25-Nov-2025', 'underlying': 'HDFCBANK', 'identifier': 'OPTSTKHDFCBANK25-11-2025CE850.00', 'openInterest': 6, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 41800, 'totalSellQuantity'
# ...

# %%
print(optionchain.keys())
# Out:
# dict_keys(['records', 'filtered'])

# %%
print(optionchain['records'].keys())
print(optionchain['records']['expiryDates'])
print(optionchain['records']['timestamp'])
print(optionchain['records']['underlyingValue'])
print(optionchain['records']['strikePrices'])
# Out:
# dict_keys(['expiryDates', 'data', 'timestamp', 'underlyingValue', 'strikePrices'])
# ['25-Nov-2025', '30-Dec-2025', '27-Jan-2026']
# 07-Nov-2025 15:30:00
# 984.3
# [800, 850, 860, 870, 880, 890, 900, 910, 915, 920, 925, 930, 935, 940, 945, 950, 955, 960, 965, 970, 975, 980, 985, 990, 995, 1000, 1005, 1010, 1015, 1020, 1025, 1030, 1035, 1040, 1045, 1050, 1055, 1060, 1065, 1070, 1080, 1090, 1100, 1110, 1120, 1130]

# %%
optionchain_df =pd.DataFrame(optionchain['records']['data'])
optionchain_df
# Out:
#      strikePrice   expiryDate  \
# 0            800  25-Nov-2025
# 1            850  25-Nov-2025
# 2            860  25-Nov-2025
# 3            860  30-Dec-2025
# 4            870  25-Nov-2025
# ..           ...          ...
# 102         1110  30-Dec-2025
# 103         1120  25-Nov-2025
# 104         1120  30-Dec-2025
# 105         1130  25-Nov-2025
# 106         1130  30-Dec-2025
#
#                                                     PE  \
# 0    {'strikePrice': 800, 'expiryDate': '25-Nov-202...
# 1    {'strikePrice': 850, 'expiryDate': '25-Nov-202...
# 2    {'strikePrice': 860, 'expiryDate': '25-Nov-202...
# 3    {'strikePrice': 860, 'expiryDate': '30-Dec-202...
# 4    {'strikePrice': 870, 'expiryDate': '25-Nov-202...
# ..                                                 ...
# 102  {'strikePrice': 1110, 'expiryDate': '30-Dec-20...
# 103  {'strikePrice': 1120, 'expiryDate': '25-Nov-20...
# 104  {'strikePrice': 1120, 'expiryDate': '30-Dec-20...
# ...

# %%
optionchain_df[(optionchain_df['strikePrice']==1500) &(optionchain_df['expiryDate']=='29-Feb-2024')]['CE'].values[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 optionchain_df[(optionchain_df['strikePrice']==1500) &(optionchain_df['expiryDate']=='29-Feb-2024')]['CE'].values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
optionchain_df[(optionchain_df['strikePrice']==1500) &(optionchain_df['expiryDate']=='29-Feb-2024')]['PE'].values[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 optionchain_df[(optionchain_df['strikePrice']==1500) &(optionchain_df['expiryDate']=='29-Feb-2024')]['PE'].values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
print(optionchain['filtered'].keys())
print(optionchain['filtered']['CE'])
print(optionchain['filtered']['PE'])
# Out:
# dict_keys(['data', 'CE', 'PE'])
# {'totOI': 63546, 'totVol': 69392}
# {'totOI': 43430, 'totVol': 40842}

# %%
### important Dates

# %%
print(nsepy.expiry_history('HDFCBANK'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 print(nsepy.expiry_history('HDFCBANK'))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nsepython\rahu.py:737, in expiry_history(symbol, start_date, end_date, type)
#     734       break
#     736 # Convert start_date and end_date to datetime objects
# --> 737 start_date = datetime.datetime.strptime(start_date, "%d-%m-%Y")
#     738 end_date = datetime.datetime.strptime(end_date, "%d-%m-%Y")
#     740 # Initialize an empty list to store filtered dates
#
# File C:\ProgramData\anaconda3\Lib\_strptime.py:673, in _strptime_datetime(cls, data_string, format)
#     670 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     671     """Return a class cls instance based on the input string and the
#     672     format string."""
# ...

# %%
print(nsepy.nse_holidays('trading'))
# Out:
# {'CBM': [{'tradingDate': '26-Jan-2025', 'weekDay': 'Sunday', 'description': 'Republic Day', 'morning_session': None, 'evening_session': None, 'Sr_no': 1}, {'tradingDate': '19-Feb-2025', 'weekDay': 'Wednesday', 'description': 'Chhatrapati Shivaji Maharaj Jayanti', 'morning_session': None, 'evening_session': None, 'Sr_no': 2}, {'tradingDate': '26-Feb-2025', 'weekDay': 'Wednesday', 'description': 'Mahashivratri', 'morning_session': None, 'evening_session': None, 'Sr_no': 3}, {'tradingDate': '14-Mar-2025', 'weekDay': 'Friday', 'description': 'Holi', 'morning_session': None, 'evening_session': None, 'Sr_no': 4}, {'tradingDate': '30-Mar-2025', 'weekDay': 'Sunday', 'description': 'Gudi Padwa', 'morning_session': None, 'evening_session': None, 'Sr_no': 5}, {'tradingDate': '31-Mar-2025', 'weekDay': 'Monday', 'description': 'Id-Ul-Fitr (Ramadan Eid)', 'morning_session': None, 'evening_session': None, 'Sr_no': 6}, {'tradingDate': '01-Apr-2025', 'weekDay': 'Tuesday', 'description': 'Annual Bank 
# ...

# %%
'Writing my first Code'
# Out:
# 'Writing my first Code'

# %% [markdown]
# ## Functions

# %% [markdown]
# ## Function: print() to pint the function

# %%
print('Hello World')
# Out:
# Hello World

# %%
print('Hello World')
print("Hello World")
print('Hello "World"')
print("Hello 'World'")
# Out:
# Hello World
# Hello World
# Hello "World"
# Hello 'World'

# %% [markdown]
# ## python Data Types

# %% [markdown]
# ## string / Integer/ Bolean / Float

# %%
## strings are  sequence of characters these coudl be numbers or alphaets or with decimals these will be the  denotes with open and closed qutations

# %%
print('Hello World')
# Out:
# Hello World

# %%
print('123456789')   ### interview question we can change the data type that is caleed Casting
# Out:
# 123456789

# %%
## function type() is to know which type of data type

# %%
type('hello world')
# Out:
# str

# %% [markdown]
# ## Data type : Integer

# %%
123456789
# Out:
# 123456789

# %%
print(1234567890)
# Out:
# 1234567890

# %%
type(1234567890)
# Out:
# int

# %%
print (type(1234567890))
# Out:
# <class 'int'>

# %%
## float are real numbers tha is number with decimal points we must have fractions in the float data type ptherwise it considered as integers f course there is no limit un end values

# %%
8.65
# Out:
# 8.65

# %%
print(5.65)
# Out:
# 5.65

# %%
type(5.65)
# Out:
# float

# %%
print(type(5.65))
# Out:
# <class 'float'>

# %%
## Data type Bolean: thus date type is bit different and it is unique can only have true or false

# %%
print(True)
# Out:
# True

# %%
print(False)
# Out:
# False

# %%
print(3==3)
# Out:
# True

# %%
print(3==6)
# Out:
# False

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
### comments in python

# %%
## this is a commented line ( its start with a # mark)

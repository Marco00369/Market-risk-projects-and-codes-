# %% [markdown]
# Market data for intrest rates

# %%
## Understding of treasury securities or marke dat of intrest rates

# %% [markdown]
# 1. Treasurt bills or oftend rweffread as T bill they sahort term debt secured that magtured in one year or less from thier isuuee date
# they are sold AT DISCOUNT  and does nit pay  any regular intrest, intead the profit is different between purchase priice and face value at maturity

# %% [markdown]
# 2. Treasury notes and treasury bonds or often refred as t notes and t bonds,they are for medium term and long term maturity, resprctive
# maturity for tnotes 2 years to 10 years
# maturity for t bonds 20 years to 30 years

# %% [markdown]
# 3. Tips treasury inflation protected securities so  they are unique type iof treasury securties specfically desgined to help investors protecrt against
# infaltion? ( the principal amount of TIPS by the consumer price index(cpi) ensuresthe pirchasing power of conasxu,er s unchange in the inflataion
#
# Intrest percdntage on TIPS is fixed

# %%
### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
USTreasuryData = pd.read_csv('https://home.treasury.gov/resource-center/data-chart-center/interest-rates/daily-treasury-rates.csv/2024/all?type=daily_treasury_yield_curve&field_tdr_date_value=2024&page&_format=csv',index_col='Date')
USTreasuryData.index = pd.to_datetime(USTreasuryData.index)
USTreasuryData
## this rates are coalled benchmarks
# Out:
#             1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# Date
# 2024-12-31  4.40  4.39  4.37  4.32  4.24  4.16  4.25  4.27  4.38  4.48   4.58
# 2024-12-30  4.43  4.42  4.37  4.33  4.25  4.17  4.24  4.29  4.37  4.46   4.55
# 2024-12-27  4.44  4.43  4.31  4.35  4.29  4.20  4.31  4.36  4.45  4.53   4.62
# 2024-12-26  4.45  4.45  4.35  4.37  4.31  4.23  4.30  4.35  4.42  4.49   4.58
# 2024-12-24  4.44  4.44  4.40  4.38  4.30  4.24  4.29  4.36  4.43  4.52   4.59
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
# 2024-01-08  5.54  5.48  5.49  5.39  5.24  4.82  4.36  4.11  3.97  3.99   4.01
# 2024-01-05  5.54  5.48  5.47  5.41  5.24  4.84  4.40  4.17  4.02  4.04   4.05
# 2024-01-04  5.56  5.48  5.48  5.41  5.25  4.85  4.38  4.14  3.97  3.99   3.99
# 2024-01-03  5.54  5.54  5.48  5.41  5.25  4.81  4.33  4.07  3.90  3.92   3.91
# 2024-01-02  5.55  5.54  5.46  5.41  5.24  4.80  4.33  4.09  3.93  3.95   3.95
#
#             20 Yr  30 Yr
# ...

# %% [markdown]
# This intrest rates changes on  daily basis were infunced by us monetary policy were decisions are made by the fedreal reserve and it could aslo change
# in infaltion and overall demand of the US securties in ter market
# any change in the underlying facgtors in the risk these intrest rate are the underlying risk factors for  the  risk facvtors
# And change the intrest rates in the markets are called market risks

# %% [markdown]
# #Module   we are going to define a claas with name

# %%
class InterestRates:

    def __init__(self,Y):
        self.Y = Y

    def USTreasury(self,ratesCurve = False, COBDate = None):
        USTreasuryData = pd.read_csv(f"https://home.treasury.gov/resource-center/data-chart-center/interest-rates/daily-treasury-rates.csv/{self.Y}/all?type=daily_treasury_yield_curve&field_tdr_date_value={self.Y}&page&_format=csv",index_col="Date")
        USTreasuryData.index = pd.to_datetime(USTreasuryData.index)
        if ratesCurve == True:
            if ratesCurve == None:
                return USTreasuryData[USTreasuryData.index == USTreasuryData.index.max()]
            else:
                return USTreasuryData[USTreasuryData.index == COBDate]
        else:
            return USTreasuryData

# %% [markdown]
# They are three most common patterns in yeild curve
# yeil curve and inverted curve and humped yeild curve

# %% [markdown]
# 01: Normal yeild curves

# %% [markdown]
# A normal yewild curve is nothing but yelid curve sloping os upwards collection of intrest rates at different trnure if the shor term is low and long tewrm high
# a curve plot ogf this intrest rates is slopping upwards than that cuerve is called Normal yeild curves
# what does it reflects?
# it defines hralty economy and denotes bull matkest
# Example the year 2003 and 2006 the us yeild curve is normal where on the yeild curve of 10 year was normal compare to yeild omnm 3 months tenure
# us stoxk market a strong growth

# %%
USTreasuryCurve = InterestRates(Y=2022).USTreasury(ratesCurve=True, COBDate=pd.to_datetime("2022-01-03"))
USTreasuryCurve
# Out:
#             1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# Date
# 2022-01-03  0.05  0.06  0.08   NaN  0.22   0.4  0.78  1.04  1.37  1.55   1.63
#
#             20 Yr  30 Yr
# Date
# 2022-01-03   2.05   2.01

# %%
plt.figure(figsize=(14,6))
plt.plot(USTreasuryCurve.transpose())
plt.title(f'USTreasury Yeild Curve, {USTreasuryCurve.index[0].date()}')
plt.xlabel('Tenor')
plt.ylabel('Interest Rates(%)')
plt.show()

# %% [markdown]
# 2.Inverted yeild curve
# is nothing but slopping downard if the shor term is high and long term is low then it was inverted yeild curve
# it genrally shows that investors have pessimisctic way
# it was considered as econonmic s=down turn ferim the economiv=c reccisinon
# example yearl 2022 the yeild curve was inverted curve this was observed at 2008 crisis

# %%
USTreasuryCurve = InterestRates(Y=2023).USTreasury(ratesCurve=True, COBDate=pd.to_datetime("2023-06-01"))
USTreasuryCurve
# Out:
#             1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# Date
# 2023-06-01   5.3  5.39   5.5   5.5  5.44  5.11  4.33  3.98   3.7  3.66   3.61
#
#             20 Yr  30 Yr
# Date
# 2023-06-01   3.98   3.84

# %%
plt.figure(figsize=(14,6))
plt.plot(USTreasuryCurve.transpose())
plt.title(f'USTreasury Yeild Curve, {USTreasuryCurve.index[0].date()}')
plt.xlabel('Tenor')
plt.ylabel('Interest Rates(%)')
plt.show()

# %% [markdown]
# #3. humped yeild curve is kind of bell shaped curve where shirt term am=nd long term arates are low and medium rated are high medium term is high
# it inidicates increase in intresrt rates in intermesdiate rates
# it kind slight hummp in yeild curves  it creates inceratainites in mixed markest
# mostly occurs in transation phase in economic example 2005-2006 the us markets are slight  seen in late as 2022

# %%
USTreasuryCurve = InterestRates(Y=2022).USTreasury(ratesCurve=True, COBDate=pd.to_datetime("2022-12-30"))
USTreasuryCurve
# Out:
#             1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# Date
# 2022-12-30  4.12  4.41  4.42  4.69  4.76  4.73  4.41  4.22  3.99  3.96   3.88
#
#             20 Yr  30 Yr
# Date
# 2022-12-30   4.14   3.97

# %%
plt.figure(figsize=(14,6))
plt.plot(USTreasuryCurve.transpose())
plt.title(f'USTreasury Yeild Curve, {USTreasuryCurve.index[0].date()}')
plt.xlabel('Tenor')
plt.ylabel('Interest Rates(%)')
plt.show()

# %%
### Historical time series data

# %%
USTreasuryData = InterestRates(Y=2023).USTreasury()
USTreasuryData
# Out:
#             1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# Date
# 2023-12-29  5.60  5.59  5.40  5.41  5.26  4.79  4.23  4.01  3.84  3.88   3.88
# 2023-12-28  5.57  5.55  5.45  5.42  5.28  4.82  4.26  4.02  3.83  3.84   3.84
# 2023-12-27  5.55  5.53  5.44  5.42  5.26  4.79  4.20  3.97  3.78  3.81   3.79
# 2023-12-26  5.53  5.52  5.45  5.44  5.28  4.83  4.26  4.05  3.89  3.91   3.89
# 2023-12-22  5.54  5.52  5.44  5.45  5.31  4.82  4.31  4.04  3.87  3.92   3.90
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
# 2023-01-09  4.37  4.58  4.70  4.74  4.83  4.69  4.19  3.93  3.66  3.60   3.53
# 2023-01-06  4.32  4.55  4.67  4.74  4.79  4.71  4.24  3.96  3.69  3.63   3.55
# 2023-01-05  4.30  4.55  4.66  4.75  4.81  4.78  4.45  4.18  3.90  3.82   3.71
# 2023-01-04  4.20  4.42  4.55  4.69  4.77  4.71  4.36  4.11  3.85  3.79   3.69
# 2023-01-03  4.17  4.42  4.53  4.70  4.77  4.72  4.40  4.18  3.94  3.89   3.79
#
#             20 Yr  30 Yr
# ...

# %%
tenors = ['6 Mo', '10 Yr', '30 Yr']

plt.figure(figsize=(14,6))
plt.plot(USTreasuryData[tenors])

plt.title('US Treasury Interest Rates')
plt.xlabel('Time')
plt.ylabel('Interest Rates (%)')
plt.legend(tenors)
plt.show()

# %%
USTreasuryData = InterestRates(Y=2024).USTreasury()
tenors = ['6 Mo', '10 Yr', '30 Yr']

plt.figure(figsize=(14,6))
plt.plot(USTreasuryData[tenors])

plt.title('US Treasury Interest Rates')
plt.xlabel('Time')
plt.ylabel('Interest Rates (%)')
plt.legend(tenors)
plt.show()

# %%
USTreasuryData = InterestRates(Y=2025).USTreasury()
tenors = ['6 Mo', '10 Yr', '30 Yr']

plt.figure(figsize=(14,6))
plt.plot(USTreasuryData[tenors])

plt.title('US Treasury Interest Rates')
plt.xlabel('Time')
plt.ylabel('Interest Rates (%)')
plt.legend(tenors)
plt.show()

# %%
pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nsepython
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import yfinance as yf
from datetime import date

# %%
date.today()
# Out:
# datetime.date(2025, 9, 4)

# %% [markdown]
# Equity spot prices

# %%
spotData = yf.download(tickers = 'HDFCBANK.NS', start = date(2020,1,1), end = date.today(), 
                       auto_adjust = False, multi_level_index = False)
spotData

##adj_close means price are after adjusting after corporate actions most relaibel for our analysisis
# Out:
# [*********************100%***********************]  1 of 1 completed
#              Adj Close       Close        High         Low        Open  \
# Date
# 2020-01-01  600.358154  639.299988  640.000000  635.299988  638.049988
# 2020-01-02  604.184937  643.375000  644.000000  639.500000  639.500000
# 2020-01-03  595.568848  634.200012  642.500000  631.799988  641.099976
# 2020-01-06  582.679749  620.474976  630.900024  618.000000  630.000000
# 2020-01-07  591.906372  630.299988  635.724976  626.125000  629.450012
# ...                ...         ...         ...         ...         ...
# 2025-08-28  957.799988  957.799988  972.200012  955.000000  967.000000
# 2025-08-29  951.599976  951.599976  963.299988  950.099976  954.000000
# 2025-09-01  950.599976  950.599976  957.450012  946.349976  949.599976
# 2025-09-02  944.500000  944.500000  954.799988  944.000000  951.000000
# 2025-09-03  954.450012  954.450012  956.299988  940.000000  945.000000
#
#               Volume
# Date
# ...

# %% [markdown]
# loc is the locationa index which helps us to performing indexing we can extract wiswe wise inmformation from the data frames insiode this loc we awant all the rows from the very beubning to yill klnow

# %%
spotData.loc[:,'Adj Close']
# Out:
# Date
# 2020-01-01    600.358154
# 2020-01-02    604.184937
# 2020-01-03    595.568848
# 2020-01-06    582.679749
# 2020-01-07    591.906372
#                  ...
# 2025-08-28    957.799988
# 2025-08-29    951.599976
# 2025-09-01    950.599976
# 2025-09-02    944.500000
# 2025-09-03    954.450012
# Name: Adj Close, Length: 1407, dtype: float64

# %%
spotData['Adj Close'].plot(figsize=(14,7) , legend = True)
# Out:
# <Axes: xlabel='Date'>

# %%
spotData = yf.download(tickers = 'HDFCBANK.NS', start = date(2024,8,10), end = date.today(), interval = '1d',
                       auto_adjust = False, multi_level_index = False)
spotData
# Out:
# [*********************100%***********************]  1 of 1 completed
#              Adj Close       Close        High         Low        Open  \
# Date
# 2024-08-12  811.985779  830.049988  837.974976  823.674988  826.000000
# 2024-08-13  784.154907  801.599976  816.200012  800.575012  814.000000
# 2024-08-14  786.404907  803.900024  806.849976  801.599976  803.250000
# 2024-08-16  798.290466  816.049988  817.075012  805.500000  814.250000
# 2024-08-19  798.021484  815.775024  818.825012  811.849976  818.825012
# ...                ...         ...         ...         ...         ...
# 2025-08-28  957.799988  957.799988  972.200012  955.000000  967.000000
# 2025-08-29  951.599976  951.599976  963.299988  950.099976  954.000000
# 2025-09-01  950.599976  950.599976  957.450012  946.349976  949.599976
# 2025-09-02  944.500000  944.500000  954.799988  944.000000  951.000000
# 2025-09-03  954.450012  954.450012  956.299988  940.000000  945.000000
#
#               Volume
# Date
# ...

# %%
stockTickers = ['ICICIBANK.NS','AXISBANK.NS']
spotData = yf.download(tickers = stockTickers, start = date(2020,1,1), end = date.today(),
                       auto_adjust = False, multi_level_index = False)
spotData
# Out:
# [*********************100%***********************]  2 of 2 completed
# Price         Adj Close                     Close                      High  \
# Ticker      AXISBANK.NS ICICIBANK.NS  AXISBANK.NS ICICIBANK.NS  AXISBANK.NS
# Date
# 2020-01-01   745.586853   519.137939   748.700012   536.750000   759.950012
# 2020-01-02   753.802612   522.861633   756.950012   540.599976   759.000000
# 2020-01-03   739.860840   521.169006   742.950012   538.849976   756.250000
# 2020-01-06   720.242737   508.450500   723.250000   525.700012   739.599976
# 2020-01-07   722.732361   505.742371   725.750000   522.900024   738.000000
# ...                 ...          ...          ...          ...          ...
# 2025-08-28  1051.900024  1399.099976  1051.900024  1399.099976  1059.500000
# 2025-08-29  1045.199951  1397.800049  1045.199951  1397.800049  1063.000000
# 2025-09-01  1061.500000  1411.000000  1061.500000  1411.000000  1064.000000
# ...

# %%
spotData ['Adj Close']
# Out:
# Ticker      AXISBANK.NS  ICICIBANK.NS
# Date
# 2020-01-01   745.586853    519.137939
# 2020-01-02   753.802612    522.861633
# 2020-01-03   739.860840    521.169006
# 2020-01-06   720.242737    508.450500
# 2020-01-07   722.732361    505.742371
# ...                 ...           ...
# 2025-08-28  1051.900024   1399.099976
# 2025-08-29  1045.199951   1397.800049
# 2025-09-01  1061.500000   1411.000000
# 2025-09-02  1056.199951   1394.199951
# 2025-09-03  1054.699951   1397.000000
#
# [1407 rows x 2 columns]

# %%
spotData['Adj Close']['ICICIBANK.NS']
# Out:
# Date
# 2020-01-01     519.137939
# 2020-01-02     522.861633
# 2020-01-03     521.169006
# 2020-01-06     508.450500
# 2020-01-07     505.742371
#                  ...
# 2025-08-28    1399.099976
# 2025-08-29    1397.800049
# 2025-09-01    1411.000000
# 2025-09-02    1394.199951
# 2025-09-03    1397.000000
# Name: ICICIBANK.NS, Length: 1407, dtype: float64

# %%
spotData['Volume']['AXISBANK.NS']
# Out:
# Date
# 2020-01-01    4917748
# 2020-01-02    5156046
# 2020-01-03    8489729
# 2020-01-06    6356198
# 2020-01-07    9103360
#                ...
# 2025-08-28    8564803
# 2025-08-29    4718016
# 2025-09-01    3190426
# 2025-09-02    4933541
# 2025-09-03    8303296
# Name: AXISBANK.NS, Length: 1407, dtype: int64

# %%
spotData['Adj Close'].plot(figsize = (14,6), legend = True)
# Out:
# <Axes: xlabel='Date'>

# %%
stockTickers = list(pd.read_csv('https://archives.nseindia.com/content/indices/top10nifty50_130325.csv')['SYMBOL'] + '.NS')
print(stockTickers)
# Out:
# ['HDFCBANK.NS', 'ICICIBANK.NS', 'RELIANCE.NS', 'INFY.NS', 'BHARTIARTL.NS', 'ITC.NS', 'LT.NS', 'TCS.NS', 'KOTAKBANK.NS', 'AXISBANK.NS']

# %%
spotData = yf.download(tickers = stockTickers, start = date(2020,1,1), end = date.today(),
                       auto_adjust = False, multi_level_index = False)
spotData
# Out:
# [*********************100%***********************]  10 of 10 completed
# Price         Adj Close                                                      \
# Ticker      AXISBANK.NS BHARTIARTL.NS HDFCBANK.NS ICICIBANK.NS      INFY.NS
# Date
# 2020-01-01   745.586853    433.316467  600.358154   519.137939   646.518677
# 2020-01-02   753.802612    435.132721  604.184937   522.861633   644.632446
# 2020-01-03   739.860840    435.037109  595.568848   521.169006   654.547058
# 2020-01-06   720.242737    429.827362  582.679749   508.450500   648.273560
# 2020-01-07   722.732361    425.477997  591.906372   505.742371   638.665955
# ...                 ...           ...         ...          ...          ...
# 2025-08-28  1051.900024   1881.099976  957.799988  1399.099976  1500.099976
# 2025-08-29  1045.199951   1888.800049  951.599976  1397.800049  1469.599976
# 2025-09-01  1061.500000   1900.599976  950.599976  1411.000000  1499.400024
# ...

# %%
spotData['Adj Close'].plot(figsize = (14,7), legend = True)
# Out:
# <Axes: xlabel='Date'>

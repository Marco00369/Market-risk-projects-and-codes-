# %%
print('hello world i am naidu from kakinada\
i want to be an quant ana;syt and present  market anaylst')
print('this is naidu')
print (' ia m aspiring quant')
# Out:
# hello world i am naidu from kakinadai want to be an quant ana;syt and present  market anaylst
# this is naidu
#  ia m aspiring quant

# %%
## varaible
a= 'kakinada'
print(type(a))
# Out:
# <class 'str'>

# %%
b=3
print(b)
print(type(b))
c=3.3
print(c)
print(type(c))
d='2025-11-13'
print(d)
print(type(d))
# Out:
# 3
# <class 'int'>
# 3.3
# <class 'float'>
# 2025-11-13
# <class 'str'>

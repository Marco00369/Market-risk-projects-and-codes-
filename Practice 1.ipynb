# %%
'Hello world iam naidu'
# Out:
# 'Hello world iam naidu'

# %%
print('hellp world i am naidu')
# Out:
# hellp world i am naidu

# %%
print(type('hellp world i am naidu'))  ##change in data types from csv files by using csasting function
# Out:
# <class 'str'>

# %%
123456789
# Out:
# 123456789

# %%
print(123456789)
# Out:
# 123456789

# %%
print(type(123456789))
# Out:
# <class 'int'>

# %%
8.56
# Out:
# 8.56

# %%
print(8.56)
# Out:
# 8.56

# %%
print(type(8.56))
# Out:
# <class 'float'>

# %%
print(True)
# Out:
# True

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
print(5==5)
# Out:
# True

# %%
print(5<3)
# Out:
# False

# %%
teststring = 'hello world  iam naidu'
testinteger = 9948978485
testfloat = 66525.645
testbolean = True

# %%
#Lets take credit card example
cc = 9948978485
print (cc)
# Out:
# 9948978485

# %%
print(teststring)
print(testinteger)
print(testfloat)
print(testbolean)
print(testinteger,teststring,testfloat,testbolean)
# Out:
# hello world  iam naidu
# 9948978485
# 66525.645
# True
# 9948978485 hello world  iam naidu 66525.645 True

# %% [markdown]
#  historical time series data instead of rembering all the data points in the time series one can store them in varaiables called stock data vvraiable/ time series varaible

# %%
test_ = teststring

# %%
print(test_)
# Out:
# hello world  iam naidu

# %%
teststring = 'hello world i am naidu' .replace('hello','hi')
##if we want to make change in varaiable but still you want original valuesto axis then we can store the value in anoother varaible
#change the value in (teststring)

# %%
print(teststring)
# Out:
# hi world i am naidu

# %%
print(test_)
# Out:
# hello world  iam naidu

# %%
##what happens test if we assigne dto test intewger to varaible

# %%
test_=testinteger
print(test_)
# Out:
# 9948978485

# %% [raw]
# ## casting function is for convertinh for one daty type to another into string, into integer intlo float

# %%
testinteger = 9948978485
print(type(str(testinteger)))
# Out:
# <class 'str'>

# %%
print(float(testinteger))
# Out:
# 9948978485.0

# %%
print(type(float(testinteger)))
# Out:
# <class 'float'>

# %%
##operators
